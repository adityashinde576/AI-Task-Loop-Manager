# %%
def run_task(n):
    for i in range(1, n + 1):
        print("Running task step", i)

        if i == 5:
            print("Task stopped early at step 5")
            break

run_task(10)
# Out:
# Running task step 1
# Running task step 2
# Running task step 3
# Running task step 4
# Running task step 5
# Task stopped early at step 5
